# %%
pip install torch torchvision medmnist matplotlib numpy
# Out:
# Requirement already satisfied: torch in C:\Users\xps\torch-env\Lib\site-packages (2.8.0)
# Requirement already satisfied: torchvision in C:\Users\xps\torch-env\Lib\site-packages (0.23.0)
# Collecting medmnist
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: matplotlib in C:\Users\xps\torch-env\Lib\site-packages (3.11.1)
# Requirement already satisfied: numpy in C:\Users\xps\torch-env\Lib\site-packages (2.5.2)
# Requirement already satisfied: filelock in C:\Users\xps\torch-env\Lib\site-packages (from torch) (3.32.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\xps\torch-env\Lib\site-packages (from torch) (4.16.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\xps\torch-env\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in C:\Users\xps\torch-env\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\xps\torch-env\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in C:\Users\xps\torch-env\Lib\site-packages (from torch) (2026.7.0)
# Requirement already satisfied: setuptools in C:\Users\xps\torch-env\Lib\site-packages (from torch) (84.0.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\xps\torch-env\Lib\site-packages (from torchvision) (12.3.0)
# Requirement already satisfied: pandas in C:\Users\xps\torch-env\Lib\site-packages (from medmnist) (3.0.5)
# Requirement already satisfied: scikit-learn in C:\Users\xps\torch-env\Lib\site-packages (from medmnist) (1.9.0)
# Collecting scikit-image (from medmnist)
#   Downloading scikit_image-0.26.0-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: tqdm in C:\Users\xps\torch-env\Lib\site-packages (from medmnist) (4.70.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\xps\torch-env\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\xps\torch-env\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\xps\torch-env\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\xps\torch-env\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\xps\torch-env\Lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pyparsing>=3 in C:\Users\xps\torch-env\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\xps\torch-env\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\xps\torch-env\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\xps\torch-env\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Collecting termcolor (from fire->medmnist)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\xps\torch-env\Lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: tzdata in C:\Users\xps\torch-env\Lib\site-packages (from pandas->medmnist) (2026.3)
# Requirement already satisfied: scipy>=1.11.4 in C:\Users\xps\torch-env\Lib\site-packages (from scikit-image->medmnist) (1.18.0)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->medmnist)
#   Downloading imageio-2.37.4-py3-none-any.whl.metadata (9.6 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->medmnist)
#   Downloading tifffile-2026.8.23-py3-none-any.whl.metadata (34 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->medmnist)
#   Downloading lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\xps\torch-env\Lib\site-packages (from scikit-learn->medmnist) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\xps\torch-env\Lib\site-packages (from scikit-learn->medmnist) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\xps\torch-env\Lib\site-packages (from scikit-learn->medmnist) (3.6.0)
# Requirement already satisfied: colorama in C:\Users\xps\torch-env\Lib\site-packages (from tqdm->medmnist) (0.4.6)
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
# Downloading scikit_image-0.26.0-cp312-cp312-win_amd64.whl (11.9 MB)
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.9 MB 493.7 kB/s eta 0:00:24
#    - -------------------------------------- 0.5/11.9 MB 493.7 kB/s eta 0:00:24
#    -- ------------------------------------- 0.8/11.9 MB 541.6 kB/s eta 0:00:21
#    -- ------------------------------------- 0.8/11.9 MB 541.6 kB/s eta 0:00:21
#    -- ------------------------------------- 0.8/11.9 MB 541.6 kB/s eta 0:00:21
#    --- ------------------------------------ 1.0/11.9 MB 541.2 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.3/11.9 MB 583.8 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.3/11.9 MB 583.8 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.3/11.9 MB 583.8 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.3/11
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ----------------------------------- ---- 10.5/11.9 MB 177.2 kB/s eta 0:00:09
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 10.7/11.9 MB 158.5 kB/s eta 0:00:08
#    ------------------------------------ --- 11.0/11.9 MB 131.3 kB/s eta 0:00:07
#    ------------------------------------ --- 11.0/11.9 MB 131.3 kB/s eta 0:00:07
#    ------------------------------------ --- 11.0/11.9 MB 131.3 kB/s eta 0:00:07
#    ------------------------------------ --- 11.0/11.9 MB 131.3 kB/s eta 0:00:07
#    ------------------------------------ --- 11.0/11.9 MB 131.3 kB/s eta 0:00:07
#    ------------------------------------- -- 11.3/11.9 MB 124.1 kB/s eta 0:00:06
#    ------------------------------------- -- 11.3/11.9 MB 124.1 kB/s eta 0:00:06
#    ------------------------------------- -- 11.3/11.9 MB 124.1 kB/s eta 0:00:06
#    ------------------------------------- -- 11.3/11.9 MB 124.1 kB/s eta 0:00:06
#    ------------------------------------- -- 11.3/11.9 MB 124.1 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/11.9 MB 123.6 kB/s eta 0:00:04
#    -------------------------------------- - 11.5/11.9 MB 123.6 kB/s eta 0:00:04
#    -------------------------------------- - 11.5/11.9 MB 123.6 kB/s eta 0:00:04
#    -------------------------------------- - 11.5/11.9 MB 123.6 kB/s eta 0:00:04
#    ---------------------------------------  11.8/11.9 MB 149.2 kB/s eta 0:00:01
#    ---------------------------------------  11.8/11.9 MB 149.2 kB/s eta 0:00:01
#    ---------------------------------------- 11.9/11.9 MB 151.8 kB/s  0:00:52
# Downloading imageio-2.37.4-py3-none-any.whl (318 kB)
# Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Downloading tifffile-2026.8.23-py3-none-any.whl (273 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: tifffile, termcolor, lazy-loader, imageio, scikit-image, fire, medmnist
#
#    ---------------------------------------- 0/7 [tifffile]
#    ---------------------------------------- 0/7 [tifffile]
#    ---------------------------------------- 0/7 [tifffile]
#    ---------------------------------------- 0/7 [tifffile]
#    ---------------------------------------- 0/7 [tifffile]
#    ---------------------------------------- 0/7 [tifffile]
#    ---------------------------------------- 0/7 [tifffile]
#    ----- ---------------------------------- 1/7 [termcolor]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ----------------- ---------------------- 3/7 [imageio]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------- ----------------- 4/7 [scikit-image]
#    ---------------------------- ----------- 5/7 [fire]
#    ---------------------------- ----------- 5/7 [fire]
#    ---------------------------- ----------- 5/7 [fire]
#    ---------------------------- ----------- 5/7 [fire]
#    ---------------------------- ----------- 5/7 [fire]
#    ---------------------------- ----------- 5/7 [fire]
#    ---------------------------- ----------- 5/7 [fire]
#    ---------------------------- ----------- 5/7 [fire]
#    ---------------------------------- ----- 6/7 [medmnist]
#    ---------------------------------------- 7/7 [medmnist]
#
# Successfully installed fire-0.7.1 imageio-2.37.4 lazy-loader-0.5 medmnist-3.0.2 scikit-image-0.26.0 termcolor-3.3.0 tifffile-2026.8.23
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
from medmnist import BloodMNIST

# %%
from medmnist import BloodMNIST
from torchvision import transforms

transform = transforms.ToTensor()

train_dataset = BloodMNIST(
    split="train",
    transform=transform,
    download=True
)

val_dataset = BloodMNIST(
    split="val",
    transform=transform,
    download=True
)

test_dataset = BloodMNIST(
    split="test",
    transform=transform,
    download=True
)

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=64,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=64,
    shuffle=False
)

# %%
import torch
import torch.nn as nn


# Select GPU if available, otherwise CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class CNN(nn.Module):

    def __init__(self):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(
                in_channels=3,
                out_channels=32,
                kernel_size=3,
                padding=1
            ),
            nn.ReLU(),

            nn.MaxPool2d(kernel_size=2),

            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                padding=1
            ),
            nn.ReLU(),

            nn.MaxPool2d(kernel_size=2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 128),
            nn.ReLU(),
            nn.Linear(128, 8)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x


model = CNN()
model = model.to(device)

print(model)
print("Using device:", device)
# Out:
# CNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=3136, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=128, out_features=8, bias=True)
#   )
# )
# Using device: cpu

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001
)

num_epochs = 10

for epoch in range(num_epochs):

    model.train()

    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:

        # Move data to GPU/CPU
        images = images.to(device)
        labels = labels.squeeze().long().to(device)

        # 1. Clear old gradients
        optimizer.zero_grad()

        # 2. Make predictions
        outputs = model(images)

        # 3. Calculate loss
        loss = criterion(outputs, labels)

        # 4. Calculate gradients
        loss.backward()

        # 5. Update model weights
        optimizer.step()

        # Keep track of loss
        running_loss += loss.item()

        # Calculate accuracy
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct / total

    print(
        f"Epoch [{epoch+1}/{num_epochs}] "
        f"Loss: {train_loss:.4f} "
        f"Accuracy: {train_accuracy:.2f}%"
    )
# Out:
# Epoch [1/10] Loss: 1.2339 Accuracy: 55.16%
# Epoch [2/10] Loss: 0.7739 Accuracy: 73.12%
# Epoch [3/10] Loss: 0.6403 Accuracy: 77.78%
# Epoch [4/10] Loss: 0.5346 Accuracy: 81.33%
# Epoch [5/10] Loss: 0.4663 Accuracy: 83.47%
# Epoch [6/10] Loss: 0.4417 Accuracy: 84.38%
# Epoch [7/10] Loss: 0.4006 Accuracy: 85.85%
# Epoch [8/10] Loss: 0.3823 Accuracy: 86.46%
# Epoch [9/10] Loss: 0.3569 Accuracy: 87.28%
# Epoch [10/10] Loss: 0.3494 Accuracy: 87.47%

# %%
model.eval()

val_correct = 0
val_total = 0

with torch.no_grad():

    for images, labels in val_loader:

        images = images.to(device)
        labels = labels.squeeze().long().to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        val_total += labels.size(0)
        val_correct += (predicted == labels).sum().item()

val_accuracy = 100 * val_correct / val_total

print(f"Validation Accuracy: {val_accuracy:.2f}%")
# Out:
# Validation Accuracy: 87.32%

# %%
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.squeeze().long().to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

test_accuracy = 100 * test_correct / test_total

print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Accuracy: 87.02%

# %%
import matplotlib.pyplot as plt

model.eval()

images, labels = next(iter(test_loader))

images = images.to(device)
labels = labels.squeeze().long().to(device)

with torch.no_grad():
    outputs = model(images)
    _, predicted = torch.max(outputs, 1)

images = images.cpu()
labels = labels.cpu()
predicted = predicted.cpu()

plt.figure(figsize=(12, 8))

for i in range(12):
    plt.subplot(3, 4, i + 1)

    # Convert CHW -> HWC for matplotlib
    plt.imshow(images[i].permute(1, 2, 0))

    plt.title(
        f"True: {labels[i].item()} | Pred: {predicted[i].item()}"
    )

    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

model.eval()

all_predictions = []
all_labels = []

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.squeeze().long().to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

cm = confusion_matrix(all_labels, all_predictions)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)

disp.plot()
plt.title("BloodMNIST Confusion Matrix")
plt.show()

# %%
torch.save(model.state_dict(), "bloodmnist_cnn.pth")

print("Model saved successfully!")
# Out:
# Model saved successfully!
